# %% [markdown]
# # Reporte de tiempo esperado de funcionamiento

# %%
def compute_average_current(high_current, high_current_time, deep_sleep_current, deep_sleep_time):
    avg_current = high_current * high_current_time + deep_sleep_current * deep_sleep_time
    avg_current /= high_current_time + deep_sleep_time
    return avg_current
    

def compute_runtime_in_battery(battery_capacity, avg_current):
    return battery_capacity / avg_current


def print_circuit_profile(tag, deep_sleep_time, bat_usable_cap, bat_runtime):
    print(f"  @{bat_usable_cap:.02f}Ah:\t{bat_runtime:.01f} hours,\t{bat_runtime/24:.02f} days\t{tag}")
    
    
def runtime_profile(tag, 
                    avg_high_current, 
                    deep_sleep_measured_current,
                    high_current_time,
                   verbose=True):
    batteries = [0.8, 2, 4, 5.5, 10] #Ah
    deep_sleep_times = [0, 10, 30, 60, 60*10, 60*15, 60*30, 60*60] #seg
    
    profiles = []
    for deep_sleep_time in deep_sleep_times:
        avg_current = compute_average_current(avg_high_current, 
                                              high_current_time, 
                                              deep_sleep_measured_current, 
                                              deep_sleep_time)
        if verbose:
            print(f"\n{tag} (run_time: {high_current_time:.2f} seg, deep_sleep_time: {deep_sleep_time:.2f} seg)")
            print(f"  average current: {avg_current * 1000:.4f} mA")

        for bat_usable_cap in batteries: #Amp hour
            bat_runtime = bat_usable_cap / avg_current
            profile = [tag, deep_sleep_time, bat_usable_cap, bat_runtime]
            profiles.append(profile)
            if verbose:
                print_circuit_profile(*profile)
    return profiles

# %%
#[board tag, run current, sleep current, time in run mode]
circuits = [
    ["test", 0.090, 1e-6, 10],
    ["wemosd1 deep_sleep", 0.080, 66e-6, 25],
    ["nodemcu relay v1", 0.135, 1e-6, 25],
    ["nodemcu DS3231+2MiSW+GPIO_Vcc", 0.080, 560e-6, 25],
    ["wemosd1 ideal", 0.080, 1e-6, 12],
    ["wemosd1 DS3231+MSW", 0.080, 1e-6, 20]
]

profiles = [runtime_profile(*c, verbose=False) for c in circuits]

# %%
#Best
for profile in profiles:
    print_circuit_profile(*profile[-1])
# Out:
#   @10.00Ah:	39951.3 hours,	1664.64 days	test
#   @10.00Ah:	16200.4 hours,	675.02 days	wemosd1 deep_sleep
#   @10.00Ah:	10729.3 hours,	447.05 days	nodemcu relay v1
#   @10.00Ah:	9026.4 hours,	376.10 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	37484.4 hours,	1561.85 days	wemosd1 ideal
#   @10.00Ah:	22574.2 hours,	940.59 days	wemosd1 DS3231+MSW

# %%
#Print all
_ = [runtime_profile(*c) for c in circuits]
# Out:
# test (run_time: 10.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 90.0000 mA
#   @0.80Ah:	8.9 hours,	0.37 days	test
#   @2.00Ah:	22.2 hours,	0.93 days	test
#   @4.00Ah:	44.4 hours,	1.85 days	test
#   @5.50Ah:	61.1 hours,	2.55 days	test
#   @10.00Ah:	111.1 hours,	4.63 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 45.0005 mA
#   @0.80Ah:	17.8 hours,	0.74 days	test
#   @2.00Ah:	44.4 hours,	1.85 days	test
#   @4.00Ah:	88.9 hours,	3.70 days	test
#   @5.50Ah:	122.2 hours,	5.09 days	test
#   @10.00Ah:	222.2 hours,	9.26 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 22.5007 mA
#   @0.80Ah:	35.6 hours,	1.48 days	test
#   @2.00Ah:	88.9 hours,	3.70 days	test
#   @4.00Ah:	177.8 hours,	7.41 days	test
#   @5.50Ah:	244.4 hours,	10.18 days	test
#   @10.00Ah:	444.4 hours,	18.52 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 12.8580 mA
#   @0.80Ah:	62.2 hours,	2.59 days	test
#   @2.00Ah:	155.5 hours,	6.48 days	test
#   @4.00Ah:	311.1 hours,	12.96 days	test
#   @5.50Ah:	427.7 hours,	17.82 days	test
#   @10.00Ah:	777.7 hours,	32.41 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 1.4764 mA
#   @0.80Ah:	541.9 hours,	22.58 days	test
#   @2.00Ah:	1354.7 hours,	56.44 days	test
#   @4.00Ah:	2709.3 hours,	112.89 days	test
#   @5.50Ah:	3725.3 hours,	155.22 days	test
#   @10.00Ah:	6773.3 hours,	282.22 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 0.9900 mA
#   @0.80Ah:	808.1 hours,	33.67 days	test
#   @2.00Ah:	2020.2 hours,	84.18 days	test
#   @4.00Ah:	4040.4 hours,	168.35 days	test
#   @5.50Ah:	5555.6 hours,	231.48 days	test
#   @10.00Ah:	10101.0 hours,	420.88 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 0.4982 mA
#   @0.80Ah:	1605.7 hours,	66.90 days	test
#   @2.00Ah:	4014.2 hours,	167.26 days	test
#   @4.00Ah:	8028.4 hours,	334.52 days	test
#   @5.50Ah:	11039.0 hours,	459.96 days	test
#   @10.00Ah:	20071.0 hours,	836.29 days	test
#
# test (run_time: 10.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.2503 mA
#   @0.80Ah:	3196.1 hours,	133.17 days	test
#   @2.00Ah:	7990.3 hours,	332.93 days	test
#   @4.00Ah:	15980.5 hours,	665.86 days	test
#   @5.50Ah:	21973.2 hours,	915.55 days	test
#   @10.00Ah:	39951.3 hours,	1664.64 days	test
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 80.0000 mA
#   @0.80Ah:	10.0 hours,	0.42 days	wemosd1 deep_sleep
#   @2.00Ah:	25.0 hours,	1.04 days	wemosd1 deep_sleep
#   @4.00Ah:	50.0 hours,	2.08 days	wemosd1 deep_sleep
#   @5.50Ah:	68.8 hours,	2.86 days	wemosd1 deep_sleep
#   @10.00Ah:	125.0 hours,	5.21 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 57.1617 mA
#   @0.80Ah:	14.0 hours,	0.58 days	wemosd1 deep_sleep
#   @2.00Ah:	35.0 hours,	1.46 days	wemosd1 deep_sleep
#   @4.00Ah:	70.0 hours,	2.92 days	wemosd1 deep_sleep
#   @5.50Ah:	96.2 hours,	4.01 days	wemosd1 deep_sleep
#   @10.00Ah:	174.9 hours,	7.29 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 36.3996 mA
#   @0.80Ah:	22.0 hours,	0.92 days	wemosd1 deep_sleep
#   @2.00Ah:	54.9 hours,	2.29 days	wemosd1 deep_sleep
#   @4.00Ah:	109.9 hours,	4.58 days	wemosd1 deep_sleep
#   @5.50Ah:	151.1 hours,	6.30 days	wemosd1 deep_sleep
#   @10.00Ah:	274.7 hours,	11.45 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 23.5760 mA
#   @0.80Ah:	33.9 hours,	1.41 days	wemosd1 deep_sleep
#   @2.00Ah:	84.8 hours,	3.53 days	wemosd1 deep_sleep
#   @4.00Ah:	169.7 hours,	7.07 days	wemosd1 deep_sleep
#   @5.50Ah:	233.3 hours,	9.72 days	wemosd1 deep_sleep
#   @10.00Ah:	424.2 hours,	17.67 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 3.2634 mA
#   @0.80Ah:	245.1 hours,	10.21 days	wemosd1 deep_sleep
#   @2.00Ah:	612.9 hours,	25.54 days	wemosd1 deep_sleep
#   @4.00Ah:	1225.7 hours,	51.07 days	wemosd1 deep_sleep
#   @5.50Ah:	1685.4 hours,	70.22 days	wemosd1 deep_sleep
#   @10.00Ah:	3064.3 hours,	127.68 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 2.2264 mA
#   @0.80Ah:	359.3 hours,	14.97 days	wemosd1 deep_sleep
#   @2.00Ah:	898.3 hours,	37.43 days	wemosd1 deep_sleep
#   @4.00Ah:	1796.6 hours,	74.86 days	wemosd1 deep_sleep
#   @5.50Ah:	2470.4 hours,	102.93 days	wemosd1 deep_sleep
#   @10.00Ah:	4491.6 hours,	187.15 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 1.1610 mA
#   @0.80Ah:	689.1 hours,	28.71 days	wemosd1 deep_sleep
#   @2.00Ah:	1722.7 hours,	71.78 days	wemosd1 deep_sleep
#   @4.00Ah:	3445.3 hours,	143.56 days	wemosd1 deep_sleep
#   @5.50Ah:	4737.4 hours,	197.39 days	wemosd1 deep_sleep
#   @10.00Ah:	8613.4 hours,	358.89 days	wemosd1 deep_sleep
#
# wemosd1 deep_sleep (run_time: 25.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.6173 mA
#   @0.80Ah:	1296.0 hours,	54.00 days	wemosd1 deep_sleep
#   @2.00Ah:	3240.1 hours,	135.00 days	wemosd1 deep_sleep
#   @4.00Ah:	6480.2 hours,	270.01 days	wemosd1 deep_sleep
#   @5.50Ah:	8910.2 hours,	371.26 days	wemosd1 deep_sleep
#   @10.00Ah:	16200.4 hours,	675.02 days	wemosd1 deep_sleep
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 135.0000 mA
#   @0.80Ah:	5.9 hours,	0.25 days	nodemcu relay v1
#   @2.00Ah:	14.8 hours,	0.62 days	nodemcu relay v1
#   @4.00Ah:	29.6 hours,	1.23 days	nodemcu relay v1
#   @5.50Ah:	40.7 hours,	1.70 days	nodemcu relay v1
#   @10.00Ah:	74.1 hours,	3.09 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 96.4289 mA
#   @0.80Ah:	8.3 hours,	0.35 days	nodemcu relay v1
#   @2.00Ah:	20.7 hours,	0.86 days	nodemcu relay v1
#   @4.00Ah:	41.5 hours,	1.73 days	nodemcu relay v1
#   @5.50Ah:	57.0 hours,	2.38 days	nodemcu relay v1
#   @10.00Ah:	103.7 hours,	4.32 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 61.3642 mA
#   @0.80Ah:	13.0 hours,	0.54 days	nodemcu relay v1
#   @2.00Ah:	32.6 hours,	1.36 days	nodemcu relay v1
#   @4.00Ah:	65.2 hours,	2.72 days	nodemcu relay v1
#   @5.50Ah:	89.6 hours,	3.73 days	nodemcu relay v1
#   @10.00Ah:	163.0 hours,	6.79 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 39.7066 mA
#   @0.80Ah:	20.1 hours,	0.84 days	nodemcu relay v1
#   @2.00Ah:	50.4 hours,	2.10 days	nodemcu relay v1
#   @4.00Ah:	100.7 hours,	4.20 days	nodemcu relay v1
#   @5.50Ah:	138.5 hours,	5.77 days	nodemcu relay v1
#   @10.00Ah:	251.8 hours,	10.49 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 5.4010 mA
#   @0.80Ah:	148.1 hours,	6.17 days	nodemcu relay v1
#   @2.00Ah:	370.3 hours,	15.43 days	nodemcu relay v1
#   @4.00Ah:	740.6 hours,	30.86 days	nodemcu relay v1
#   @5.50Ah:	1018.3 hours,	42.43 days	nodemcu relay v1
#   @10.00Ah:	1851.5 hours,	77.15 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 3.6496 mA
#   @0.80Ah:	219.2 hours,	9.13 days	nodemcu relay v1
#   @2.00Ah:	548.0 hours,	22.83 days	nodemcu relay v1
#   @4.00Ah:	1096.0 hours,	45.67 days	nodemcu relay v1
#   @5.50Ah:	1507.0 hours,	62.79 days	nodemcu relay v1
#   @10.00Ah:	2740.0 hours,	114.17 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 1.8503 mA
#   @0.80Ah:	432.4 hours,	18.02 days	nodemcu relay v1
#   @2.00Ah:	1080.9 hours,	45.04 days	nodemcu relay v1
#   @4.00Ah:	2161.8 hours,	90.08 days	nodemcu relay v1
#   @5.50Ah:	2972.5 hours,	123.85 days	nodemcu relay v1
#   @10.00Ah:	5404.5 hours,	225.19 days	nodemcu relay v1
#
# nodemcu relay v1 (run_time: 25.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.9320 mA
#   @0.80Ah:	858.3 hours,	35.76 days	nodemcu relay v1
#   @2.00Ah:	2145.9 hours,	89.41 days	nodemcu relay v1
#   @4.00Ah:	4291.7 hours,	178.82 days	nodemcu relay v1
#   @5.50Ah:	5901.1 hours,	245.88 days	nodemcu relay v1
#   @10.00Ah:	10729.3 hours,	447.05 days	nodemcu relay v1
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 80.0000 mA
#   @0.80Ah:	10.0 hours,	0.42 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	25.0 hours,	1.04 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	50.0 hours,	2.08 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	68.8 hours,	2.86 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	125.0 hours,	5.21 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 57.3029 mA
#   @0.80Ah:	14.0 hours,	0.58 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	34.9 hours,	1.45 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	69.8 hours,	2.91 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	96.0 hours,	4.00 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	174.5 hours,	7.27 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 36.6691 mA
#   @0.80Ah:	21.8 hours,	0.91 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	54.5 hours,	2.27 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	109.1 hours,	4.55 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	150.0 hours,	6.25 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	272.7 hours,	11.36 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 23.9247 mA
#   @0.80Ah:	33.4 hours,	1.39 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	83.6 hours,	3.48 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	167.2 hours,	6.97 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	229.9 hours,	9.58 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	418.0 hours,	17.42 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 3.7376 mA
#   @0.80Ah:	214.0 hours,	8.92 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	535.1 hours,	22.30 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	1070.2 hours,	44.59 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	1471.5 hours,	61.31 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	2675.5 hours,	111.48 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 2.7070 mA
#   @0.80Ah:	295.5 hours,	12.31 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	738.8 hours,	30.78 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	1477.6 hours,	61.57 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	2031.7 hours,	84.66 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	3694.1 hours,	153.92 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 1.6482 mA
#   @0.80Ah:	485.4 hours,	20.22 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	1213.4 hours,	50.56 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	2426.9 hours,	101.12 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	3336.9 hours,	139.04 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	6067.2 hours,	252.80 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# nodemcu DS3231+2MiSW+GPIO_Vcc (run_time: 25.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 1.1079 mA
#   @0.80Ah:	722.1 hours,	30.09 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @2.00Ah:	1805.3 hours,	75.22 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @4.00Ah:	3610.6 hours,	150.44 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @5.50Ah:	4964.5 hours,	206.85 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#   @10.00Ah:	9026.4 hours,	376.10 days	nodemcu DS3231+2MiSW+GPIO_Vcc
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 80.0000 mA
#   @0.80Ah:	10.0 hours,	0.42 days	wemosd1 ideal
#   @2.00Ah:	25.0 hours,	1.04 days	wemosd1 ideal
#   @4.00Ah:	50.0 hours,	2.08 days	wemosd1 ideal
#   @5.50Ah:	68.8 hours,	2.86 days	wemosd1 ideal
#   @10.00Ah:	125.0 hours,	5.21 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 43.6368 mA
#   @0.80Ah:	18.3 hours,	0.76 days	wemosd1 ideal
#   @2.00Ah:	45.8 hours,	1.91 days	wemosd1 ideal
#   @4.00Ah:	91.7 hours,	3.82 days	wemosd1 ideal
#   @5.50Ah:	126.0 hours,	5.25 days	wemosd1 ideal
#   @10.00Ah:	229.2 hours,	9.55 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 22.8579 mA
#   @0.80Ah:	35.0 hours,	1.46 days	wemosd1 ideal
#   @2.00Ah:	87.5 hours,	3.65 days	wemosd1 ideal
#   @4.00Ah:	175.0 hours,	7.29 days	wemosd1 ideal
#   @5.50Ah:	240.6 hours,	10.03 days	wemosd1 ideal
#   @10.00Ah:	437.5 hours,	18.23 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 13.3342 mA
#   @0.80Ah:	60.0 hours,	2.50 days	wemosd1 ideal
#   @2.00Ah:	150.0 hours,	6.25 days	wemosd1 ideal
#   @4.00Ah:	300.0 hours,	12.50 days	wemosd1 ideal
#   @5.50Ah:	412.5 hours,	17.19 days	wemosd1 ideal
#   @10.00Ah:	750.0 hours,	31.25 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 1.5696 mA
#   @0.80Ah:	509.7 hours,	21.24 days	wemosd1 ideal
#   @2.00Ah:	1274.2 hours,	53.09 days	wemosd1 ideal
#   @4.00Ah:	2548.4 hours,	106.18 days	wemosd1 ideal
#   @5.50Ah:	3504.1 hours,	146.00 days	wemosd1 ideal
#   @10.00Ah:	6371.0 hours,	265.46 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 1.0536 mA
#   @0.80Ah:	759.3 hours,	31.64 days	wemosd1 ideal
#   @2.00Ah:	1898.2 hours,	79.09 days	wemosd1 ideal
#   @4.00Ah:	3796.4 hours,	158.19 days	wemosd1 ideal
#   @5.50Ah:	5220.1 hours,	217.50 days	wemosd1 ideal
#   @10.00Ah:	9491.1 hours,	395.46 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 0.5308 mA
#   @0.80Ah:	1507.2 hours,	62.80 days	wemosd1 ideal
#   @2.00Ah:	3767.9 hours,	157.00 days	wemosd1 ideal
#   @4.00Ah:	7535.9 hours,	313.99 days	wemosd1 ideal
#   @5.50Ah:	10361.8 hours,	431.74 days	wemosd1 ideal
#   @10.00Ah:	18839.7 hours,	784.99 days	wemosd1 ideal
#
# wemosd1 ideal (run_time: 12.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.2668 mA
#   @0.80Ah:	2998.8 hours,	124.95 days	wemosd1 ideal
#   @2.00Ah:	7496.9 hours,	312.37 days	wemosd1 ideal
#   @4.00Ah:	14993.8 hours,	624.74 days	wemosd1 ideal
#   @5.50Ah:	20616.4 hours,	859.02 days	wemosd1 ideal
#   @10.00Ah:	37484.4 hours,	1561.85 days	wemosd1 ideal
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 80.0000 mA
#   @0.80Ah:	10.0 hours,	0.42 days	wemosd1 DS3231+MSW
#   @2.00Ah:	25.0 hours,	1.04 days	wemosd1 DS3231+MSW
#   @4.00Ah:	50.0 hours,	2.08 days	wemosd1 DS3231+MSW
#   @5.50Ah:	68.8 hours,	2.86 days	wemosd1 DS3231+MSW
#   @10.00Ah:	125.0 hours,	5.21 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 53.3337 mA
#   @0.80Ah:	15.0 hours,	0.62 days	wemosd1 DS3231+MSW
#   @2.00Ah:	37.5 hours,	1.56 days	wemosd1 DS3231+MSW
#   @4.00Ah:	75.0 hours,	3.12 days	wemosd1 DS3231+MSW
#   @5.50Ah:	103.1 hours,	4.30 days	wemosd1 DS3231+MSW
#   @10.00Ah:	187.5 hours,	7.81 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 32.0006 mA
#   @0.80Ah:	25.0 hours,	1.04 days	wemosd1 DS3231+MSW
#   @2.00Ah:	62.5 hours,	2.60 days	wemosd1 DS3231+MSW
#   @4.00Ah:	125.0 hours,	5.21 days	wemosd1 DS3231+MSW
#   @5.50Ah:	171.9 hours,	7.16 days	wemosd1 DS3231+MSW
#   @10.00Ah:	312.5 hours,	13.02 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 20.0008 mA
#   @0.80Ah:	40.0 hours,	1.67 days	wemosd1 DS3231+MSW
#   @2.00Ah:	100.0 hours,	4.17 days	wemosd1 DS3231+MSW
#   @4.00Ah:	200.0 hours,	8.33 days	wemosd1 DS3231+MSW
#   @5.50Ah:	275.0 hours,	11.46 days	wemosd1 DS3231+MSW
#   @10.00Ah:	500.0 hours,	20.83 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 2.5816 mA
#   @0.80Ah:	309.9 hours,	12.91 days	wemosd1 DS3231+MSW
#   @2.00Ah:	774.7 hours,	32.28 days	wemosd1 DS3231+MSW
#   @4.00Ah:	1549.4 hours,	64.56 days	wemosd1 DS3231+MSW
#   @5.50Ah:	2130.5 hours,	88.77 days	wemosd1 DS3231+MSW
#   @10.00Ah:	3873.5 hours,	161.40 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 1.7401 mA
#   @0.80Ah:	459.7 hours,	19.16 days	wemosd1 DS3231+MSW
#   @2.00Ah:	1149.4 hours,	47.89 days	wemosd1 DS3231+MSW
#   @4.00Ah:	2298.7 hours,	95.78 days	wemosd1 DS3231+MSW
#   @5.50Ah:	3160.7 hours,	131.70 days	wemosd1 DS3231+MSW
#   @10.00Ah:	5746.8 hours,	239.45 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 0.8801 mA
#   @0.80Ah:	909.0 hours,	37.87 days	wemosd1 DS3231+MSW
#   @2.00Ah:	2272.4 hours,	94.69 days	wemosd1 DS3231+MSW
#   @4.00Ah:	4544.9 hours,	189.37 days	wemosd1 DS3231+MSW
#   @5.50Ah:	6249.2 hours,	260.38 days	wemosd1 DS3231+MSW
#   @10.00Ah:	11362.2 hours,	473.43 days	wemosd1 DS3231+MSW
#
# wemosd1 DS3231+MSW (run_time: 20.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.4430 mA
#   @0.80Ah:	1805.9 hours,	75.25 days	wemosd1 DS3231+MSW
#   @2.00Ah:	4514.8 hours,	188.12 days	wemosd1 DS3231+MSW
#   @4.00Ah:	9029.7 hours,	376.24 days	wemosd1 DS3231+MSW
#   @5.50Ah:	12415.8 hours,	517.33 days	wemosd1 DS3231+MSW
#   @10.00Ah:	22574.2 hours,	940.59 days	wemosd1 DS3231+MSW

# %% [markdown]
# # Tests

# %%
tag = "test_circuit" #Usar para identificar el circuito
avg_high_current = 0.080 #A
deep_sleep_measured_current = 1e-6 #A
run_time = 15 #s

runtime_profile(tag, avg_high_current, deep_sleep_measured_current, run_time)
# Out:
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 0.00 seg)
#   average current: 80.0000 mA
#   @0.80Ah:	10.0 hours,	0.42 days	test_circuit
#   @2.00Ah:	25.0 hours,	1.04 days	test_circuit
#   @4.00Ah:	50.0 hours,	2.08 days	test_circuit
#   @5.50Ah:	68.8 hours,	2.86 days	test_circuit
#   @10.00Ah:	125.0 hours,	5.21 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 10.00 seg)
#   average current: 48.0004 mA
#   @0.80Ah:	16.7 hours,	0.69 days	test_circuit
#   @2.00Ah:	41.7 hours,	1.74 days	test_circuit
#   @4.00Ah:	83.3 hours,	3.47 days	test_circuit
#   @5.50Ah:	114.6 hours,	4.77 days	test_circuit
#   @10.00Ah:	208.3 hours,	8.68 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 30.00 seg)
#   average current: 26.6673 mA
#   @0.80Ah:	30.0 hours,	1.25 days	test_circuit
#   @2.00Ah:	75.0 hours,	3.12 days	test_circuit
#   @4.00Ah:	150.0 hours,	6.25 days	test_circuit
#   @5.50Ah:	206.2 hours,	8.59 days	test_circuit
#   @10.00Ah:	375.0 hours,	15.62 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 60.00 seg)
#   average current: 16.0008 mA
#   @0.80Ah:	50.0 hours,	2.08 days	test_circuit
#   @2.00Ah:	125.0 hours,	5.21 days	test_circuit
#   @4.00Ah:	250.0 hours,	10.42 days	test_circuit
#   @5.50Ah:	343.7 hours,	14.32 days	test_circuit
#   @10.00Ah:	625.0 hours,	26.04 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 600.00 seg)
#   average current: 1.9522 mA
#   @0.80Ah:	409.8 hours,	17.07 days	test_circuit
#   @2.00Ah:	1024.5 hours,	42.69 days	test_circuit
#   @4.00Ah:	2049.0 hours,	85.37 days	test_circuit
#   @5.50Ah:	2817.3 hours,	117.39 days	test_circuit
#   @10.00Ah:	5122.4 hours,	213.43 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 900.00 seg)
#   average current: 1.3125 mA
#   @0.80Ah:	609.5 hours,	25.40 days	test_circuit
#   @2.00Ah:	1523.9 hours,	63.49 days	test_circuit
#   @4.00Ah:	3047.7 hours,	126.99 days	test_circuit
#   @5.50Ah:	4190.6 hours,	174.61 days	test_circuit
#   @10.00Ah:	7619.3 hours,	317.47 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 1800.00 seg)
#   average current: 0.6621 mA
#   @0.80Ah:	1208.2 hours,	50.34 days	test_circuit
#   @2.00Ah:	3020.5 hours,	125.85 days	test_circuit
#   @4.00Ah:	6040.9 hours,	251.71 days	test_circuit
#   @5.50Ah:	8306.3 hours,	346.10 days	test_circuit
#   @10.00Ah:	15102.3 hours,	629.26 days	test_circuit
#
# test_circuit (run_time: 15.00 seg, deep_sleep_time: 3600.00 seg)
#   average current: 0.3329 mA
#   @0.80Ah:	2402.8 hours,	100.12 days	test_circuit
#   @2.00Ah:	6007.0 hours,	250.29 days	test_circuit
#   @4.00Ah:	12014.0 hours,	500.58 days	test_circuit
#   @5.50Ah:	16519.2 hours,	688.30 days	test_circuit
#   @10.00Ah:	30034.9 hours,	1251.45 days	test_circuit
# [['test_circuit', 0, 0.8, 10.0],
#  ['test_circuit', 0, 2, 25.0],
#  ['test_circuit', 0, 4, 50.0],
#  ['test_circuit', 0, 5.5, 68.75],
#  ['test_circuit', 0, 10, 125.0],
#  ['test_circuit', 10, 0.8, 16.666527778935176],
#  ['test_circuit', 10, 2, 41.66631944733794],
#  ['test_circuit', 10, 4, 83.33263889467588],
#  ['test_circuit', 10, 5.5, 114.58237848017933],
#  ['test_circuit', 10, 10, 208.3315972366897],
#  ['test_circuit', 30, 0.8, 29.999250018749535],
#  ['test_circuit', 30, 2, 74.99812504687384],
#  ['test_circuit', 30, 4, 149.99625009374768],
#  ['test_circuit', 30, 5.5, 206.24484387890305],
#  ['test_circuit', 30, 10, 374.9906252343692],
#  ['test_circuit', 60, 0.8, 49.997500124993756],
#  ['test_circuit', 60, 2, 124.99375031248438],
#  ['test_circuit', 60, 4, 249.98750062496876],
#  ['test_circuit', 60, 5.5, 343.73281335933206],
#  ['test_circuit', 60, 10, 624.968751562422],
#  ['test_circuit', 600, 0.8, 409.79510244877565],
#  ['test_circuit', 600, 2, 1024.4877561219391],
#  ['test_circuit', 600, 4, 2048.9755122438783],
#  ['test_circuit', 600, 5.5, 2817.3413293353324],
#  ['test_circuit', 600, 10, 5122.438780609696],
#  ['test_circuit', 900, 0.8, 609.5428428678491],
#  ['test_circuit', 900, 2, 1523.8571071696229],
#  ['test_circuit', 900, 4, 3047.7142143392457],
#  ['test_circuit', 900, 5.5, 4190.607044716463],
#  ['test_circuit', 900, 10, 7619.285535848114],
#  ['test_circuit', 1800, 0.8, 1208.1877184223665],
#  ['test_circuit', 1800, 2, 3020.469296055916],
#  ['test_circuit', 1800, 4, 6040.938592111832],
#  ['test_circuit', 1800, 5.5, 8306.290564153769],
#  ['test_circuit', 1800, 10, 15102.34648027958],
#  ['test_circuit', 3600, 0.8, 2402.791625124626],
#  ['test_circuit', 3600, 2, 6006.979062811565],
#  ['test_circuit', 3600, 4, 12013.95812562313],
#  ['test_circuit', 3600, 5.5, 16519.192422731805],
#  ['test_circuit', 3600, 10, 30034.895314057827]]
