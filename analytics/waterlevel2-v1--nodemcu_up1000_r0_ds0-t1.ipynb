# %% [markdown]
# # WaterLevel with Deep Sleep v1

# %%
from collections import defaultdict
import json
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture

# %%
experiment = "waterlevel2"
power_profiler_freq = 10 #ms
board="nodemcu"
r = 0 #s run time (0 => no deep sleep)
ds = 0 #s deep_sleep time (0 => no deep sleep)
update_interval = 1000 #ms
test_num = 1 #test_number

#Analisys
batteries = [0.8, 2, 4, 10] #Ah
deep_sleep_times = [0, 10, 30, 60, 600, 1800, 3600]

# %% [markdown]
# ## Code

# %%
def load_data(filename, show=False):
    try:
        df = pd.read_csv(filename)
        if show:
            display(df.head())
    except FileNotFoundError:
        print(f"Error: '{fn}' not found.")
    except pd.errors.ParserError:
        print("Error: Unable to parse the CSV file. Check the file format.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return df

# %%
def preprocess(df): 
    '''
    Check for missing values
    '''
    missing_values = df['current'].isnull().sum()
    missing_percentage = (missing_values / len(df['current'])) * 100
    print(f"Missing values in 'current' column: {missing_values} ({missing_percentage:.2f}%)")

    # Determine data type and convert if necessary
    print(f"Original data type of 'current' column: {df['current'].dtype}")
    if not pd.api.types.is_numeric_dtype(df['current']):
        try:
            df['current'] = pd.to_numeric(df['current'], errors='coerce')
            print("Converted 'current' column to numeric type.")
        except Exception as e:
            print(f"Error converting 'current' column: {e}")
    print(f"Data type of 'current' column after conversion: {df['current'].dtype}")

    # Calculate descriptive statistics
    descriptive_stats = df['current'].describe()
    print("\nDescriptive Statistics for 'current' column:")
    print(descriptive_stats)
    return df

# %% [markdown]
# **Reasoning**:
# Clean the 'current' column by removing outliers using the IQR method and impute any remaining missing values with the median.
#
#
# **NOTA: ALGO SE VE RARO EN ESTO, REVISAR EL MÉTODO, PUEDE SER QUE NO ELIMINE NADA **

# %%
def clean(df):
    quantile_low = 0.25
    quantile_high = 0.75
    iqr_factor = 1.5

    # Calculate Q1, Q3, and IQR
    Q1 = df['current'].quantile(quantile_low)
    Q3 = df['current'].quantile(quantile_high)
    IQR = Q3 - Q1

    # Define bounds for outlier removal
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"IQR lower_bound: {lower_bound}, upper_bound: {upper_bound})")

    # Remove outliers
    org_len = len(df['current'])
    df = df[~((df['current'] < lower_bound) | (df['current'] > upper_bound))]
    removed_len = len(df['current'])
    print(f"Length before IQR bounds: {org_len}, after: {removed_len}")

    # Display descriptive statistics after outlier removal
    print("\nDescriptive Statistics for 'current' column after outlier removal:")
    print(df['current'].describe())

    # Handle any remaining missing values
    if df['current'].isnull().any():
        median_current = df['current'].median()
        df['current'].fillna(median_current, inplace=True)
        print("\nDescriptive Statistics for 'current' column after imputation:")
        print(df['current'].describe())
    else:
        print("\nNo missing values found after outlier removal.")
    return df

# %%
def gmm_fit(data, plot_results=False):
    """
    Finds a current threshold to separate high and low current usage modes using Gaussian Mixture Models.

    Args:
        data (pd.Series or np.array): The current usage data.
        plot_results (bool, optional): Whether to plot the histogram and GMM fit. Defaults to False.

    Returns:
        float: The current threshold separating the modes, or None if the fitting fails.
        array of means
        array of labels
    """

    if isinstance(data, pd.Series):
        data = data.values.reshape(-1, 1) #Reshape for sklearn
    elif isinstance(data, np.ndarray):
        data = data.reshape(-1, 1)
    else:
        raise TypeError("Input data must be a pandas Series or numpy array.")

    try:
        gmm = GaussianMixture(n_components=2)
        labels = gmm.fit_predict(data)
        means = gmm.means_.flatten()
        means.sort()  # Ensure means are sorted: low, high

        # Calculate the threshold as the midpoint between the means
        threshold = (means[0] + means[1]) / 2

        if plot_results:
            plt.hist(data, bins=50, density=True, alpha=0.6, color='g')
            x = np.linspace(data.min(), data.max(), 200).reshape(-1, 1)
            logprob = gmm.score_samples(x)
            pdf = np.exp(logprob)
            plt.plot(x, pdf, '-r')
            plt.axvline(threshold, color='b', linestyle='--', label=f'Threshold: {threshold:.4f}')
            plt.axvline(means[0], color="#888888", linestyle="--", label=f"Mean 0: {means[0]:.4f}")
            plt.axvline(means[1], color="#888888", linestyle="--", label=f"Mean 1: {means[1]:.4f}")
            plt.legend()
            plt.xlabel("Current")
            plt.ylabel("Density")
            plt.title("Current Usage Distribution and GMM Fit")
            plt.show()

        return threshold, means, labels

    except Exception as e:
        print(f"Error during GMM fitting: {e}")
        return None

#Example Usage
# Create a sample dataset (replace with your actual data)

# %%
def analyze_cycles(df):
    """
    Analyzes and separates high current usage cycles and deep sleep periods.
    """
    
    cycles = []
    # Iterate over the DataFrame and check for transitions between high and low current states.
    # This is a simplified representation, and the logic may need adjustment based on your specific requirements
    current_state = None
    start_time = None
    for index, row in df.iterrows():
        if row['state_label'] == "high":
            if current_state != "high":  # Transition to high current state
                if current_state == "low":
                    cycles.append({"state":"low", "start_time":start_time, "end_time": row['read_at']})
                current_state = "high"
                start_time = row['read_at']
        else:
            if current_state != "low":  # Transition to low current state
                if current_state == "high":
                    cycles.append({"state":"high", "start_time":start_time, "end_time": row['read_at']})
                current_state = "low"
                start_time = row['read_at']

    # Handle the last cycle
    if start_time:
        cycles.append({"state":current_state, "start_time":start_time, "end_time": df['read_at'].iloc[-1]})

    return cycles

# %% [markdown]
# ## Analysis

# %%
experiment_name = f"{board}_up{update_interval}_r{r}_ds{ds}-t{test_num}"
filename = f"../data/{experiment}-f{power_profiler_freq}--{experiment_name}.csv"
print(experiment_name)
print(filename)
df = load_data(filename, True)
# Out:
# nodemcu_up1000_r0_ds0-t1
# ../data/waterlevel2-f10--nodemcu_up1000_r0_ds0-t1.csv
#    index                     read_at  millis            timestamp  voltage  \
# 0      0  2025-03-12 18:33:12.879518  303431  2025-03-12 18:33:12    5.064
# 1      1  2025-03-12 18:33:12.880387  303443  2025-03-12 18:33:12    5.064
# 2      2  2025-03-12 18:33:12.881059  303453  2025-03-12 18:33:12    5.064
# 3      3  2025-03-12 18:33:12.881679  303464  2025-03-12 18:33:12    5.064
# 4      4  2025-03-12 18:33:12.882343  303475  2025-03-12 18:33:12    5.064
#
#    current    power  bus_voltage
# 0   0.0836  0.42335      0.00836
# 1   0.0836  0.42335      0.00836
# 2   0.0820  0.41525      0.00820
# 3   0.0820  0.41525      0.00820
# 4   0.0832  0.42132      0.00832

# %%
# Convert 'read_at' to datetime objects
df['read_at'] = pd.to_datetime(df['read_at'])

# Calculate descriptive statistics
descriptive_stats = df['current'].describe()
print("Descriptive Statistics for 'current' column:")
print(descriptive_stats)

# Analyze trends using rolling mean
df['rolling_mean'] = df['current'].rolling(window=5, center=False).mean()

threshold, means, labels = gmm_fit(df.current, plot_results=True)
# Out:
# Descriptive Statistics for 'current' column:
# count    5276.000000
# mean        0.083276
# std         0.001987
# min         0.080000
# 25%         0.082800
# 50%         0.083200
# 75%         0.083200
# max         0.123200
# Name: current, dtype: float64

# %%
# Visualize trends and anomalies
plt.figure(figsize=(15, 8))
plt.plot(df['read_at'], df['current'], label='Current', color='blue')
plt.plot(df['read_at'], df['rolling_mean'], label='Rolling Mean', color='red')

plt.xlabel('read_at')
plt.ylabel('Current')
plt.title('Current Consumption over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['read_at'], df['current'], color="gray")
plt.scatter(df['read_at'], df['current'], label='Current', c=labels, cmap=ListedColormap(["blue", "red"]))
#plt.axhline(threshold, color='b', linestyle='--', label=f"threshold={threshold:.4f}")
plt.legend()

# %%
states = ["low", "high"]
if means[0] > means[1]:
    states = ["high", "low"]
df['state_label'] = [states[l] for l in labels]

# %%
for index, state in zip([0, 1], states):
    print(f"Average current in {state}: {means[index]}")
# Out:
# Average current in low: 0.0829941175272336
# Average current in high: 0.09060961868011941

# %%
cycles = analyze_cycles(df)

# Example calculations for each cycle
durations = defaultdict(list)
#Excluir la primera y ultima fases capturadas porque estan incompletas
print("State\tStart\tEnd\tDuration")
for cycle in cycles[1:-1]:
    duration = cycle['end_time'] - cycle['start_time']
    durations[cycle['state']].append(duration.total_seconds())
    print(f"{cycle['state']}\t{cycle['start_time']}\t{cycle['end_time']}\t{duration}")
    # Add other calculations as needed (e.g., average current within the cycle, energy consumption)

average_durations = {state: (sum(d) / len(d)) for state, d in durations.items()}
print(f"Average durations: {average_durations}")
# Out:
# State	Start	End	Duration
# high	2025-03-12 18:33:13.275621	2025-03-12 18:33:13.305584	0 days 00:00:00.029963
# low	2025-03-12 18:33:13.305584	2025-03-12 18:33:14.295665	0 days 00:00:00.990081
# high	2025-03-12 18:33:14.295665	2025-03-12 18:33:14.306555	0 days 00:00:00.010890
# low	2025-03-12 18:33:14.306555	2025-03-12 18:33:14.355699	0 days 00:00:00.049144
# high	2025-03-12 18:33:14.355699	2025-03-12 18:33:14.375674	0 days 00:00:00.019975
# low	2025-03-12 18:33:14.375674	2025-03-12 18:33:14.795674	0 days 00:00:00.420000
# high	2025-03-12 18:33:14.795674	2025-03-12 18:33:14.815686	0 days 00:00:00.020012
# low	2025-03-12 18:33:14.815686	2025-03-12 18:33:15.275636	0 days 00:00:00.459950
# high	2025-03-12 18:33:15.275636	2025-03-12 18:33:15.305661	0 days 00:00:00.030025
# low	2025-03-12 18:33:15.305661	2025-03-12 18:33:15.875604	0 days 00:00:00.569943
# high	2025-03-12 18:33:15.875604	2025-03-12 18:33:15.895669	0 days 00:00:00.020065
# low	2025-03-12 18:33:15.895669	2025-03-12 18:33:16.295635	0 days 00:00:00.399966
# high	2025-03-12 18:33:16.295635	2025-03-12 18:33:16.305688	0 days 00:00:00.010053
# low	2025-03-12 18:33:16.305688	2025-03-12 18:33:17.285693	0 days 00:00:00.980005
# high	2025-03-12 18:33:17.285693	2025-03-12 18:33:17.305717	0 days 00:00:00.020024
# low	2025-03-12 18:33:17.305717	2025-03-12 18:33:17.435722	0 days 00:00:00.130005
# high	2025-03-12 18:33:17.435722	2025-03-12 18:33:17.446533	0 days 00:00:00.010811
# low	2025-03-12 18:33:17.446533	2025-03-12 18:33:18.285703	0 days 00:00:00.839170
# high	2025-03-12 18:33:18.285703	2025-03-12 18:33:18.305733	0 days 00:00:00.020030
# low	2025-03-12 18:33:18.305733	2025-03-12 18:33:18.355676	0 days 00:00:00.049943
# high	2025-03-12 18:33:18.355676	2025-03-12 18:33:18.365669	0 days 00:00:00.009993
# low	2025-03-12 18:33:18.365669	2025-03-12 18:33:19.035779	0 days 00:00:00.670110
# high	2025-03-12 18:33:19.035779	2025-03-12 18:33:19.046635	0 days 00:00:00.010856
# low	2025-03-12 18:33:19.046635	2025-03-12 18:33:19.285785	0 days 00:00:00.239150
# high	2025-03-12 18:33:19.285785	2025-03-12 18:33:19.305804	0 days 00:00:00.020019
# low	2025-03-12 18:33:19.305804	2025-03-12 18:33:21.286666	0 days 00:00:01.980862
# high	2025-03-12 18:33:21.286666	2025-03-12 18:33:21.306502	0 days 00:00:00.019836
# low	2025-03-12 18:33:21.306502	2025-03-12 18:33:22.286579	0 days 00:00:00.980077
# high	2025-03-12 18:33:22.286579	2025-03-12 18:33:22.316607	0 days 00:00:00.030028
# low	2025-03-12 18:33:22.316607	2025-03-12 18:33:22.507610	0 days 00:00:00.191003
# high	2025-03-12 18:33:22.507610	2025-03-12 18:33:22.531705	0 days 00:00:00.024095
# low	2025-03-12 18:33:22.531705	2025-03-12 18:33:22.771676	0 days 00:00:00.239971
# high	2025-03-12 18:33:22.771676	2025-03-12 18:33:22.804927	0 days 00:00:00.033251
# low	2025-03-12 18:33:22.804927	2025-03-12 18:33:23.026602	0 days 00:00:00.221675
# high	2025-03-12 18:33:23.026602	2025-03-12 18:33:23.081644	0 days 00:00:00.055042
# low	2025-03-12 18:33:23.081644	2025-03-12 18:33:23.091760	0 days 00:00:00.010116
# high	2025-03-12 18:33:23.091760	2025-03-12 18:33:23.114553	0 days 00:00:00.022793
# low	2025-03-12 18:33:23.114553	2025-03-12 18:33:23.124644	0 days 00:00:00.010091
# high	2025-03-12 18:33:23.124644	2025-03-12 18:33:23.136646	0 days 00:00:00.012002
# low	2025-03-12 18:33:23.136646	2025-03-12 18:33:23.202654	0 days 00:00:00.066008
# high	2025-03-12 18:33:23.202654	2025-03-12 18:33:23.224669	0 days 00:00:00.022015
# low	2025-03-12 18:33:23.224669	2025-03-12 18:33:23.282572	0 days 00:00:00.057903
# high	2025-03-12 18:33:23.282572	2025-03-12 18:33:23.303635	0 days 00:00:00.021063
# low	2025-03-12 18:33:23.303635	2025-03-12 18:33:24.286619	0 days 00:00:00.982984
# high	2025-03-12 18:33:24.286619	2025-03-12 18:33:24.307587	0 days 00:00:00.020968
# low	2025-03-12 18:33:24.307587	2025-03-12 18:33:24.462744	0 days 00:00:00.155157
# high	2025-03-12 18:33:24.462744	2025-03-12 18:33:24.474744	0 days 00:00:00.012000
# low	2025-03-12 18:33:24.474744	2025-03-12 18:33:24.553688	0 days 00:00:00.078944
# high	2025-03-12 18:33:24.553688	2025-03-12 18:33:24.565600	0 days 00:00:00.011912
# low	2025-03-12 18:33:24.565600	2025-03-12 18:33:25.288707	0 days 00:00:00.723107
# high	2025-03-12 18:33:25.288707	2025-03-12 18:33:25.299599	0 days 00:00:00.010892
# low	2025-03-12 18:33:25.299599	2025-03-12 18:33:25.476582	0 days 00:00:00.176983
# high	2025-03-12 18:33:25.476582	2025-03-12 18:33:25.496738	0 days 00:00:00.020156
# low	2025-03-12 18:33:25.496738	2025-03-12 18:33:25.553722	0 days 00:00:00.056984
# high	2025-03-12 18:33:25.553722	2025-03-12 18:33:25.565622	0 days 00:00:00.011900
# low	2025-03-12 18:33:25.565622	2025-03-12 18:33:26.278726	0 days 00:00:00.713104
# high	2025-03-12 18:33:26.278726	2025-03-12 18:33:26.300695	0 days 00:00:00.021969
# low	2025-03-12 18:33:26.300695	2025-03-12 18:33:26.467636	0 days 00:00:00.166941
# high	2025-03-12 18:33:26.467636	2025-03-12 18:33:26.488749	0 days 00:00:00.021113
# low	2025-03-12 18:33:26.488749	2025-03-12 18:33:26.546683	0 days 00:00:00.057934
# high	2025-03-12 18:33:26.546683	2025-03-12 18:33:26.567738	0 days 00:00:00.021055
# low	2025-03-12 18:33:26.567738	2025-03-12 18:33:26.771672	0 days 00:00:00.203934
# high	2025-03-12 18:33:26.771672	2025-03-12 18:33:26.793696	0 days 00:00:00.022024
# low	2025-03-12 18:33:26.793696	2025-03-12 18:33:27.285127	0 days 00:00:00.491431
# high	2025-03-12 18:33:27.285127	2025-03-12 18:33:27.326720	0 days 00:00:00.041593
# low	2025-03-12 18:33:27.326720	2025-03-12 18:33:27.471712	0 days 00:00:00.144992
# high	2025-03-12 18:33:27.471712	2025-03-12 18:33:27.482589	0 days 00:00:00.010877
# low	2025-03-12 18:33:27.482589	2025-03-12 18:33:28.278736	0 days 00:00:00.796147
# high	2025-03-12 18:33:28.278736	2025-03-12 18:33:28.310808	0 days 00:00:00.032072
# low	2025-03-12 18:33:28.310808	2025-03-12 18:33:29.283773	0 days 00:00:00.972965
# high	2025-03-12 18:33:29.283773	2025-03-12 18:33:29.305625	0 days 00:00:00.021852
# low	2025-03-12 18:33:29.305625	2025-03-12 18:33:30.294657	0 days 00:00:00.989032
# high	2025-03-12 18:33:30.294657	2025-03-12 18:33:30.305639	0 days 00:00:00.010982
# low	2025-03-12 18:33:30.305639	2025-03-12 18:33:30.582818	0 days 00:00:00.277179
# high	2025-03-12 18:33:30.582818	2025-03-12 18:33:30.594747	0 days 00:00:00.011929
# low	2025-03-12 18:33:30.594747	2025-03-12 18:33:31.276657	0 days 00:00:00.681910
# high	2025-03-12 18:33:31.276657	2025-03-12 18:33:31.306751	0 days 00:00:00.030094
# low	2025-03-12 18:33:31.306751	2025-03-12 18:33:32.290688	0 days 00:00:00.983937
# high	2025-03-12 18:33:32.290688	2025-03-12 18:33:32.312785	0 days 00:00:00.022097
# low	2025-03-12 18:33:32.312785	2025-03-12 18:33:33.289693	0 days 00:00:00.976908
# high	2025-03-12 18:33:33.289693	2025-03-12 18:33:33.311683	0 days 00:00:00.021990
# low	2025-03-12 18:33:33.311683	2025-03-12 18:33:34.289732	0 days 00:00:00.978049
# high	2025-03-12 18:33:34.289732	2025-03-12 18:33:34.300712	0 days 00:00:00.010980
# low	2025-03-12 18:33:34.300712	2025-03-12 18:33:34.387649	0 days 00:00:00.086937
# high	2025-03-12 18:33:34.387649	2025-03-12 18:33:34.399796	0 days 00:00:00.012147
# low	2025-03-12 18:33:34.399796	2025-03-12 18:33:34.684673	0 days 00:00:00.284877
# high	2025-03-12 18:33:34.684673	2025-03-12 18:33:34.705838	0 days 00:00:00.021165
# low	2025-03-12 18:33:34.705838	2025-03-12 18:33:35.286844	0 days 00:00:00.581006
# high	2025-03-12 18:33:35.286844	2025-03-12 18:33:35.309795	0 days 00:00:00.022951
# low	2025-03-12 18:33:35.309795	2025-03-12 18:33:35.703701	0 days 00:00:00.393906
# high	2025-03-12 18:33:35.703701	2025-03-12 18:33:35.714798	0 days 00:00:00.011097
# low	2025-03-12 18:33:35.714798	2025-03-12 18:33:36.289765	0 days 00:00:00.574967
# high	2025-03-12 18:33:36.289765	2025-03-12 18:33:36.299802	0 days 00:00:00.010037
# low	2025-03-12 18:33:36.299802	2025-03-12 18:33:37.296749	0 days 00:00:00.996947
# high	2025-03-12 18:33:37.296749	2025-03-12 18:33:37.307802	0 days 00:00:00.011053
# low	2025-03-12 18:33:37.307802	2025-03-12 18:33:38.286831	0 days 00:00:00.979029
# high	2025-03-12 18:33:38.286831	2025-03-12 18:33:38.308672	0 days 00:00:00.021841
# low	2025-03-12 18:33:38.308672	2025-03-12 18:33:39.297712	0 days 00:00:00.989040
# high	2025-03-12 18:33:39.297712	2025-03-12 18:33:39.308748	0 days 00:00:00.011036
# low	2025-03-12 18:33:39.308748	2025-03-12 18:33:40.286810	0 days 00:00:00.978062
# high	2025-03-12 18:33:40.286810	2025-03-12 18:33:40.307834	0 days 00:00:00.021024
# low	2025-03-12 18:33:40.307834	2025-03-12 18:33:41.283833	0 days 00:00:00.975999
# high	2025-03-12 18:33:41.283833	2025-03-12 18:33:41.294873	0 days 00:00:00.011040
# low	2025-03-12 18:33:41.294873	2025-03-12 18:33:42.276841	0 days 00:00:00.981968
# high	2025-03-12 18:33:42.276841	2025-03-12 18:33:42.297765	0 days 00:00:00.020924
# low	2025-03-12 18:33:42.297765	2025-03-12 18:33:43.293821	0 days 00:00:00.996056
# high	2025-03-12 18:33:43.293821	2025-03-12 18:33:43.315778	0 days 00:00:00.021957
# low	2025-03-12 18:33:43.315778	2025-03-12 18:33:44.282865	0 days 00:00:00.967087
# high	2025-03-12 18:33:44.282865	2025-03-12 18:33:44.293802	0 days 00:00:00.010937
# low	2025-03-12 18:33:44.293802	2025-03-12 18:33:45.282921	0 days 00:00:00.989119
# high	2025-03-12 18:33:45.282921	2025-03-12 18:33:45.293803	0 days 00:00:00.010882
# low	2025-03-12 18:33:45.293803	2025-03-12 18:33:46.292877	0 days 00:00:00.999074
# high	2025-03-12 18:33:46.292877	2025-03-12 18:33:46.313860	0 days 00:00:00.020983
# low	2025-03-12 18:33:46.313860	2025-03-12 18:33:47.279916	0 days 00:00:00.966056
# high	2025-03-12 18:33:47.279916	2025-03-12 18:33:47.312790	0 days 00:00:00.032874
# low	2025-03-12 18:33:47.312790	2025-03-12 18:33:47.477922	0 days 00:00:00.165132
# high	2025-03-12 18:33:47.477922	2025-03-12 18:33:47.498792	0 days 00:00:00.020870
# low	2025-03-12 18:33:47.498792	2025-03-12 18:33:48.291814	0 days 00:00:00.793022
# high	2025-03-12 18:33:48.291814	2025-03-12 18:33:48.303736	0 days 00:00:00.011922
# low	2025-03-12 18:33:48.303736	2025-03-12 18:33:49.291857	0 days 00:00:00.988121
# high	2025-03-12 18:33:49.291857	2025-03-12 18:33:49.303811	0 days 00:00:00.011954
# low	2025-03-12 18:33:49.303811	2025-03-12 18:33:50.035744	0 days 00:00:00.731933
# high	2025-03-12 18:33:50.035744	2025-03-12 18:33:50.046935	0 days 00:00:00.011191
# low	2025-03-12 18:33:50.046935	2025-03-12 18:33:50.289891	0 days 00:00:00.242956
# high	2025-03-12 18:33:50.289891	2025-03-12 18:33:50.300918	0 days 00:00:00.011027
# low	2025-03-12 18:33:50.300918	2025-03-12 18:33:50.414950	0 days 00:00:00.114032
# high	2025-03-12 18:33:50.414950	2025-03-12 18:33:50.436862	0 days 00:00:00.021912
# low	2025-03-12 18:33:50.436862	2025-03-12 18:33:51.293919	0 days 00:00:00.857057
# high	2025-03-12 18:33:51.293919	2025-03-12 18:33:51.304834	0 days 00:00:00.010915
# low	2025-03-12 18:33:51.304834	2025-03-12 18:33:52.293817	0 days 00:00:00.988983
# high	2025-03-12 18:33:52.293817	2025-03-12 18:33:52.303933	0 days 00:00:00.010116
# low	2025-03-12 18:33:52.303933	2025-03-12 18:33:53.075925	0 days 00:00:00.771992
# high	2025-03-12 18:33:53.075925	2025-03-12 18:33:53.096921	0 days 00:00:00.020996
# low	2025-03-12 18:33:53.096921	2025-03-12 18:33:53.173957	0 days 00:00:00.077036
# high	2025-03-12 18:33:53.173957	2025-03-12 18:33:53.196805	0 days 00:00:00.022848
# low	2025-03-12 18:33:53.196805	2025-03-12 18:33:53.284833	0 days 00:00:00.088028
# high	2025-03-12 18:33:53.284833	2025-03-12 18:33:53.306889	0 days 00:00:00.022056
# low	2025-03-12 18:33:53.306889	2025-03-12 18:33:53.935908	0 days 00:00:00.629019
# high	2025-03-12 18:33:53.935908	2025-03-12 18:33:53.957973	0 days 00:00:00.022065
# low	2025-03-12 18:33:53.957973	2025-03-12 18:33:54.234828	0 days 00:00:00.276855
# high	2025-03-12 18:33:54.234828	2025-03-12 18:33:54.267940	0 days 00:00:00.033112
# low	2025-03-12 18:33:54.267940	2025-03-12 18:33:54.289823	0 days 00:00:00.021883
# high	2025-03-12 18:33:54.289823	2025-03-12 18:33:54.322952	0 days 00:00:00.033129
# low	2025-03-12 18:33:54.322952	2025-03-12 18:33:55.289926	0 days 00:00:00.966974
# high	2025-03-12 18:33:55.289926	2025-03-12 18:33:55.300834	0 days 00:00:00.010908
# low	2025-03-12 18:33:55.300834	2025-03-12 18:33:55.528850	0 days 00:00:00.228016
# high	2025-03-12 18:33:55.528850	2025-03-12 18:33:55.540861	0 days 00:00:00.012011
# low	2025-03-12 18:33:55.540861	2025-03-12 18:33:56.286943	0 days 00:00:00.746082
# high	2025-03-12 18:33:56.286943	2025-03-12 18:33:56.308900	0 days 00:00:00.021957
# low	2025-03-12 18:33:56.308900	2025-03-12 18:33:56.548875	0 days 00:00:00.239975
# high	2025-03-12 18:33:56.548875	2025-03-12 18:33:56.560899	0 days 00:00:00.012024
# low	2025-03-12 18:33:56.560899	2025-03-12 18:33:57.285844	0 days 00:00:00.724945
# high	2025-03-12 18:33:57.285844	2025-03-12 18:33:57.296971	0 days 00:00:00.011127
# low	2025-03-12 18:33:57.296971	2025-03-12 18:33:57.549812	0 days 00:00:00.252841
# high	2025-03-12 18:33:57.549812	2025-03-12 18:33:57.570864	0 days 00:00:00.021052
# low	2025-03-12 18:33:57.570864	2025-03-12 18:33:58.285997	0 days 00:00:00.715133
# high	2025-03-12 18:33:58.285997	2025-03-12 18:33:58.328943	0 days 00:00:00.042946
# low	2025-03-12 18:33:58.328943	2025-03-12 18:33:59.285880	0 days 00:00:00.956937
# high	2025-03-12 18:33:59.285880	2025-03-12 18:33:59.295041	0 days 00:00:00.009161
# low	2025-03-12 18:33:59.295041	2025-03-12 18:34:00.283913	0 days 00:00:00.988872
# high	2025-03-12 18:34:00.283913	2025-03-12 18:34:00.317913	0 days 00:00:00.034000
# low	2025-03-12 18:34:00.317913	2025-03-12 18:34:01.282981	0 days 00:00:00.965068
# high	2025-03-12 18:34:01.282981	2025-03-12 18:34:01.315942	0 days 00:00:00.032961
# low	2025-03-12 18:34:01.315942	2025-03-12 18:34:01.676937	0 days 00:00:00.360995
# high	2025-03-12 18:34:01.676937	2025-03-12 18:34:01.687904	0 days 00:00:00.010967
# low	2025-03-12 18:34:01.687904	2025-03-12 18:34:02.273850	0 days 00:00:00.585946
# high	2025-03-12 18:34:02.273850	2025-03-12 18:34:02.306026	0 days 00:00:00.032176
# low	2025-03-12 18:34:02.306026	2025-03-12 18:34:03.295754	0 days 00:00:00.989728
# high	2025-03-12 18:34:03.295754	2025-03-12 18:34:03.305846	0 days 00:00:00.010092
# low	2025-03-12 18:34:03.305846	2025-03-12 18:34:04.067020	0 days 00:00:00.761174
# high	2025-03-12 18:34:04.067020	2025-03-12 18:34:04.100885	0 days 00:00:00.033865
# low	2025-03-12 18:34:04.100885	2025-03-12 18:34:04.297918	0 days 00:00:00.197033
# high	2025-03-12 18:34:04.297918	2025-03-12 18:34:04.308073	0 days 00:00:00.010155
# low	2025-03-12 18:34:04.308073	2025-03-12 18:34:05.290898	0 days 00:00:00.982825
# high	2025-03-12 18:34:05.290898	2025-03-12 18:34:05.302051	0 days 00:00:00.011153
# low	2025-03-12 18:34:05.302051	2025-03-12 18:34:06.292944	0 days 00:00:00.990893
# high	2025-03-12 18:34:06.292944	2025-03-12 18:34:06.304092	0 days 00:00:00.011148
# low	2025-03-12 18:34:06.304092	2025-03-12 18:34:07.290918	0 days 00:00:00.986826
# high	2025-03-12 18:34:07.290918	2025-03-12 18:34:07.302195	0 days 00:00:00.011277
# low	2025-03-12 18:34:07.302195	2025-03-12 18:34:08.287090	0 days 00:00:00.984895
# high	2025-03-12 18:34:08.287090	2025-03-12 18:34:08.319111	0 days 00:00:00.032021
# low	2025-03-12 18:34:08.319111	2025-03-12 18:34:09.289722	0 days 00:00:00.970611
# high	2025-03-12 18:34:09.289722	2025-03-12 18:34:09.311055	0 days 00:00:00.021333
# low	2025-03-12 18:34:09.311055	2025-03-12 18:34:10.288970	0 days 00:00:00.977915
# high	2025-03-12 18:34:10.288970	2025-03-12 18:34:10.309943	0 days 00:00:00.020973
# low	2025-03-12 18:34:10.309943	2025-03-12 18:34:11.286121	0 days 00:00:00.976178
# high	2025-03-12 18:34:11.286121	2025-03-12 18:34:11.297004	0 days 00:00:00.010883
# low	2025-03-12 18:34:11.297004	2025-03-12 18:34:11.461928	0 days 00:00:00.164924
# high	2025-03-12 18:34:11.461928	2025-03-12 18:34:11.473984	0 days 00:00:00.012056
# low	2025-03-12 18:34:11.473984	2025-03-12 18:34:12.291010	0 days 00:00:00.817026
# high	2025-03-12 18:34:12.291010	2025-03-12 18:34:12.301941	0 days 00:00:00.010931
# low	2025-03-12 18:34:12.301941	2025-03-12 18:34:12.411937	0 days 00:00:00.109996
# high	2025-03-12 18:34:12.411937	2025-03-12 18:34:12.433985	0 days 00:00:00.022048
# Average durations: {'high': 0.019243113402061852, 'low': 0.5967893958333332}

# %%
for cycle in cycles[1:-1]:
    # Filter the DataFrame to include only data points within the current cycle
    cycle_data = df[(df['read_at'] >= cycle['start_time']) & (df['read_at'] <= cycle['end_time'])]

    # Calculate the average current for the current cycle
    avg_current = cycle_data['current'].mean()

    # Print the average current for the current cycle
    print(f"Average Current for Cycle ({cycle['state']}): {avg_current:.4f} A")
# Out:
# Average Current for Cycle (high): 0.0870 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0878 A
# Average Current for Cycle (low): 0.0851 A
# Average Current for Cycle (high): 0.0888 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0860 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0867 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0859 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0866 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0913 A
# Average Current for Cycle (low): 0.0835 A
# Average Current for Cycle (high): 0.0854 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0907 A
# Average Current for Cycle (low): 0.0843 A
# Average Current for Cycle (high): 0.0852 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0854 A
# Average Current for Cycle (low): 0.0836 A
# Average Current for Cycle (high): 0.0944 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0948 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0887 A
# Average Current for Cycle (low): 0.0840 A
# Average Current for Cycle (high): 0.0889 A
# Average Current for Cycle (low): 0.0836 A
# Average Current for Cycle (high): 0.0876 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0892 A
# Average Current for Cycle (low): 0.0880 A
# Average Current for Cycle (high): 0.0873 A
# Average Current for Cycle (low): 0.0876 A
# Average Current for Cycle (high): 0.0870 A
# Average Current for Cycle (low): 0.0835 A
# Average Current for Cycle (high): 0.0864 A
# Average Current for Cycle (low): 0.0868 A
# Average Current for Cycle (high): 0.0999 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0896 A
# Average Current for Cycle (low): 0.0839 A
# Average Current for Cycle (high): 0.0844 A
# Average Current for Cycle (low): 0.0825 A
# Average Current for Cycle (high): 0.0856 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0912 A
# Average Current for Cycle (low): 0.0838 A
# Average Current for Cycle (high): 0.0864 A
# Average Current for Cycle (low): 0.0845 A
# Average Current for Cycle (high): 0.0872 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0933 A
# Average Current for Cycle (low): 0.0838 A
# Average Current for Cycle (high): 0.0860 A
# Average Current for Cycle (low): 0.0839 A
# Average Current for Cycle (high): 0.0859 A
# Average Current for Cycle (low): 0.0856 A
# Average Current for Cycle (high): 0.1097 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0875 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0852 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0867 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0864 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0882 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0854 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0873 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0875 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0913 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0890 A
# Average Current for Cycle (low): 0.0847 A
# Average Current for Cycle (high): 0.0882 A
# Average Current for Cycle (low): 0.0836 A
# Average Current for Cycle (high): 0.0864 A
# Average Current for Cycle (low): 0.0835 A
# Average Current for Cycle (high): 0.0912 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0854 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0918 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0920 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0940 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0910 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0937 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0900 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0931 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0881 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0894 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0878 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0873 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0873 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0859 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0864 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0866 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0858 A
# Average Current for Cycle (low): 0.0839 A
# Average Current for Cycle (high): 0.0918 A
# Average Current for Cycle (low): 0.0838 A
# Average Current for Cycle (high): 0.0860 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0904 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0900 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0893 A
# Average Current for Cycle (low): 0.0847 A
# Average Current for Cycle (high): 0.0857 A
# Average Current for Cycle (low): 0.0845 A
# Average Current for Cycle (high): 0.0941 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0861 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0860 A
# Average Current for Cycle (low): 0.0851 A
# Average Current for Cycle (high): 0.0879 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0918 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0852 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0936 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0854 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0920 A
# Average Current for Cycle (low): 0.0834 A
# Average Current for Cycle (high): 0.0857 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0867 A
# Average Current for Cycle (low): 0.0828 A
# Average Current for Cycle (high): 0.0902 A
# Average Current for Cycle (low): 0.0827 A
# Average Current for Cycle (high): 0.0876 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0869 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0852 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0874 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0882 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0859 A
# Average Current for Cycle (low): 0.0833 A
# Average Current for Cycle (high): 0.0886 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0880 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0870 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0920 A
# Average Current for Cycle (low): 0.0831 A
# Average Current for Cycle (high): 0.0924 A
# Average Current for Cycle (low): 0.0830 A
# Average Current for Cycle (high): 0.0928 A
# Average Current for Cycle (low): 0.0832 A
# Average Current for Cycle (high): 0.0943 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0916 A
# Average Current for Cycle (low): 0.0843 A
# Average Current for Cycle (high): 0.0872 A
# Average Current for Cycle (low): 0.0829 A
# Average Current for Cycle (high): 0.0916 A
# Average Current for Cycle (low): 0.0838 A
# Average Current for Cycle (high): 0.0857 A

# %% [markdown]
# ## Battery predictions
#
# ### deep sleep as measured by power_profiler

# %%
avg_high_current = means[states.index('high')]
avg_low_current = means[states.index('low')]

batteries = [0.8, 2, 4, 10] #Ah
avg_current = avg_high_current * average_durations['high'] + avg_low_current * average_durations['low']
avg_current /= average_durations['high'] + average_durations['low']
print(f"Average current: {avg_current * 1000:.2f} mA")

for bat_usable_cap in batteries: #Amp hour
    runtime = bat_usable_cap / avg_current
    print(f"At {bat_usable_cap:.02f}Ah:\t{runtime:.01f} hours,\t{runtime/24:.02f} days")
# Out:
# Average current: 83.23 mA
# At 0.80Ah:	9.6 hours,	0.40 days
# At 2.00Ah:	24.0 hours,	1.00 days
# At 4.00Ah:	48.1 hours,	2.00 days
# At 10.00Ah:	120.1 hours,	5.01 days

# %% [markdown]
# ### deep sleep current measured by multimeter

# %%
boards = json.loads(open("../data/boards.json").read())
boards
# Out:
# {'nodemcu': {'current': {'deep_sleep': 0.0092}},
#  'saola': {'current': {'deep_sleep': 0.0009}},
#  'wemosd1': {'current': {'deep_sleep': 6.5e-05}},
#  'wemosc3mini': {'current': {'deep_sleep': 0.000418}}}

# %%
deep_sleep_measured_current = boards[board]["current"]["deep_sleep"]

avg_current = avg_high_current * average_durations['high'] + deep_sleep_measured_current * average_durations['low']
avg_current /= average_durations['high'] + average_durations['low']
print(f"Average current: {avg_current * 1000:.2f} mA")

for bat_usable_cap in batteries: #Amp hour
    runtime = bat_usable_cap / avg_current
    print(f"At {bat_usable_cap:.02f}Ah:\t{runtime:.01f} hours,\t{runtime/24:.02f} days")
# Out:
# Average current: 11.74 mA
# At 0.80Ah:	68.1 hours,	2.84 days
# At 2.00Ah:	170.3 hours,	7.10 days
# At 4.00Ah:	340.6 hours,	14.19 days
# At 10.00Ah:	851.6 hours,	35.48 days

# %% [markdown]
# ### predicitions on measured deep sleep

# %%
run_time = average_durations['high']
for deep_sleep_time in deep_sleep_times:
    avg_current = avg_high_current * run_time + deep_sleep_measured_current * deep_sleep_time
    avg_current /= run_time + deep_sleep_time
    print(f"\n{board} run_time: {run_time:.2f} seg, deep_sleep_time: {deep_sleep_time:.2f} seg")
    print(f"  average current: {avg_current * 1000:.4f} mA")

    for bat_usable_cap in batteries: #Amp hour
        bat_runtime = bat_usable_cap / avg_current
        print(f"  At {bat_usable_cap:.02f}Ah:\t{bat_runtime:.01f} hours,\t{bat_runtime/24:.02f} days")
# Out:
# nodemcu run_time: 0.02 seg, deep_sleep_time: 0.00 seg
#   average current: 90.6096 mA
#   At 0.80Ah:	8.8 hours,	0.37 days
#   At 2.00Ah:	22.1 hours,	0.92 days
#   At 4.00Ah:	44.1 hours,	1.84 days
#   At 10.00Ah:	110.4 hours,	4.60 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 10.00 seg
#   average current: 9.3564 mA
#   At 0.80Ah:	85.5 hours,	3.56 days
#   At 2.00Ah:	213.8 hours,	8.91 days
#   At 4.00Ah:	427.5 hours,	17.81 days
#   At 10.00Ah:	1068.8 hours,	44.53 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 30.00 seg
#   average current: 9.2522 mA
#   At 0.80Ah:	86.5 hours,	3.60 days
#   At 2.00Ah:	216.2 hours,	9.01 days
#   At 4.00Ah:	432.3 hours,	18.01 days
#   At 10.00Ah:	1080.8 hours,	45.03 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 60.00 seg
#   average current: 9.2261 mA
#   At 0.80Ah:	86.7 hours,	3.61 days
#   At 2.00Ah:	216.8 hours,	9.03 days
#   At 4.00Ah:	433.6 hours,	18.06 days
#   At 10.00Ah:	1083.9 hours,	45.16 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 600.00 seg
#   average current: 9.2026 mA
#   At 0.80Ah:	86.9 hours,	3.62 days
#   At 2.00Ah:	217.3 hours,	9.06 days
#   At 4.00Ah:	434.7 hours,	18.11 days
#   At 10.00Ah:	1086.6 hours,	45.28 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 1800.00 seg
#   average current: 9.2009 mA
#   At 0.80Ah:	86.9 hours,	3.62 days
#   At 2.00Ah:	217.4 hours,	9.06 days
#   At 4.00Ah:	434.7 hours,	18.11 days
#   At 10.00Ah:	1086.9 hours,	45.29 days
#
# nodemcu run_time: 0.02 seg, deep_sleep_time: 3600.00 seg
#   average current: 9.2004 mA
#   At 0.80Ah:	87.0 hours,	3.62 days
#   At 2.00Ah:	217.4 hours,	9.06 days
#   At 4.00Ah:	434.8 hours,	18.12 days
#   At 10.00Ah:	1086.9 hours,	45.29 days
